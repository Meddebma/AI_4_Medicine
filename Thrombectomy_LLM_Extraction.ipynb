# %% [markdown]
# # Evaluating Open-Source Large Language Models for Data Extraction from Unstructured Reports on Mechanical Thrombectomy in Patients with Ischemic Stroke
#
# Welcome to this notebook that will show you how to extract data from Thrombectomy reports using Mistral-7b AI locally on a Single GPU
#
# In this notebook we load and run Mistral-7b with QLoRA which is a 4bit quantization technique with no performance degradation.

# %%
#Install packages
# !pip install -q -U bitsandbytes
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git

# %% [markdown]
# ## Step 2 - Define quantization parameters through the BitsandBytesConfig from transformers
#
#
# * load_in_4bit=True: specify that we want to convert and load the model in 4-bit precision.
# * bnb_4bit_use_double_quant=True: Use nested quantization for more memory efficient inference and training.
# * bnd_4bit_quant_type="nf4": The 4bit integration comes with 2 different quantization types FP4 and NF4. The NF4 dtype stands for Normal Float 4 and is introduced in the QLoRA paper. By default, the FP4 quantization is used.
# * bnb_4bit_compute_dype=torch.bfloat16: The compute dtype is used to change the dtype that will be used during computation. By default, the compute dtype is set to float32 but computation can be set to bf16 for speedups.

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# %%
import json
import pandas as pd
import time
from datetime import timedelta
from IPython.display import display, HTML

# %% [markdown]
# ## Step 3 - Load the Model with quantization

# %%
model_id = "mistralai/Mistral-7B-Instruct-v0.2"
#model_id ="BioMistral/BioMistral-7B"
#model_id = "mistralai/Mixtral-8x7B-Instruct-v0.1"
#model_id = "HuggingFaceH4/zephyr-7b-beta"
#model_id = "argilla/notus-7b-v1"
model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=bnb_config, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(model_id)

# %% [markdown]
# # Step 4 - Define prompts examples and JSON template

# %%
json_template = {
  "NIHSS_score": "",
  "symptom_onset":"",
  "occluded_vessel":"",
  "occlusion_side":"",
  "used_materials":"",
  "medication": "",
  "complications": "",
  "outcome": "",
  "TICI_score": "",
  "Area dose product": "",
  "Fluoroscopy time": "",
  "arrival_time": "",
  "puncture_time": "",
  "first_series_time": "",
  "artery_opening_time": ""
  }

instructions= {
    "NIHSS_score": "Der NIHSS (National Institutes of Health Stroke Scale) Wert des Patienten. Eine Messung, die verwendet wird, um die Beeinträchtigung durch einen Schlaganfall zu quantifizieren. Erwartet wird eine ganze Zahl zwischen 0 und 42.",
    "symptom_onset": "Die Zeit, zu der der Patient zum ersten Mal Symptome bemerkte. Erwartetes Format: 'HH:MM'.",
    "occluded_vessel": "Das verstopfte Blutgefäß. Mögliche Werte umfassen spezifische Arterien wie ACI, M1, M2, Basillaris usw.",
    "occlusion_side": "Die Seite des Körpers, auf der die Okklusion lokalisiert ist. Erwartete Werte: 'links', 'rechts', 'nicht zutreffend', 'unklar'.",
    "used_materials": "Die neurointerventionellen Materialien, die während des Verfahrens verwendet wurden. Dies kann Schleusen, Katheter, Ballons, Führungsdraht, Stentretriever und Stents umfassen. Kontrastmittel und Angioanlage nicht berücksichtigen",
    "medication": "Details zu Medikamenten, die dem Patienten während oder nach dem Verfahren verabreicht wurden, Kontrastmittel nicht berücksichtigen.",
    "complications": "Komplikationen, die während des Verfahrens aufgetreten sind. Dieses Feld sollte den Typ oder die Natur der Komplikation beschreiben, falls zutreffend.",
    "outcome": "Das Ergebnis des Verfahrens, das angibt, ob es erfolgreich, teilweise erfolgreich oder erfolglos war.",
    "TICI_score": "Der TICI (Thrombolysis in Cerebral Infarction) Wert nach dem Verfahren, der das Niveau des wiederhergestellten Blutflusses im verstopften Bereich darstellt.",
    "Area dose product": "Die gesamte während des Verfahrens verwendete Strahlendosis, gemessen in Gy*cm².",
    "Fluoroscopy time": "Die Gesamtzeit, in der die Fluoroskopie-Bildgebungstechnik während des Verfahrens verwendet wurde. Typischerweise gemessen in Minuten oder Sekunden.",
    "arrival_time": "Die Zeit, zu der der Patient für das Verfahren in der Einrichtung ankam. Erwartetes Format: 'HH:MM'.",
    "puncture_time": "Die Zeit, zu der die Punktion gemacht wurde, um auf das verstopfte Gefäß zuzugreifen. Erwartetes Format: 'HH:MM'.",
    "first_series_time": "Die Zeit der ersten Serie von angiografischen Bildern, die während des Verfahrens aufgenommen wurden. Erwartetes Format: 'HH:MM'.",
    "artery_opening_time": "Die Zeit, zu der die Arterie während des Verfahrens erfolgreich geöffnet wurde. Erwartetes Format: 'HH:MM'."
}

# %% [markdown]
# # Import Data and load into Dataframe

# %%
import pandas as pd
df= pd.read_csv ('thrombectomy.csv')

# %% [markdown]
# # Zero-shot-Prompting

# %%
# Only display output (two columns/ BioMistral)

device = "cuda:0"

# Convert JSON template and expected outputs to string format
json_template_str = json.dumps(json_template, ensure_ascii=False, indent=2)


# Function to generate a prompt for each report
def generate_prompt(report, json_template):
    prompt = (f"Bitte analysieren Sie den folgenden Bericht und extrahieren Sie die Daten, um die JSON-Vorlage auszufüllen."
              f"Die Antwort soll ausschließlich auf Deutsch erfolgen. Befolgen Sie dabei die folgenden Beschreibungen:\n"
              f"{instructions}\n"
              f"Hier ist die JSON-Vorlage zum Ausfüllen:\n"
              f"{json_template_str}\n\n"
              f"Report:\n"
              f"{report_text}")

    return Prompt



# Function to process each report
def process_report(report):
    start_time = time.time()  # Start timing
    prompt = generate_prompt(report, json_template)
    encodeds = tokenizer.apply_chat_template(prompt, tokenize=True, padding=True, return_tensors="pt").to(device)  # Use prompt directly
    generated_ids = model.generate(encodeds, max_new_tokens=1000, do_sample=True)
    decoded = tokenizer.batch_decode(generated_ids)

    #Extracting the JSON string from the response
    json_start_pattern = "Output:"
    json_end_pattern = "}"
    try:
        json_start_index = decoded[0].find(json_start_pattern) + len(json_start_pattern)
        json_end_index = decoded[0].find(json_end_pattern, json_start_index) + 1  # +1 to include the closing brace
        json_str = decoded[0][json_start_index:json_end_index]
        return json_str.strip()  # Removing leading/trailing whitespace
    except ValueError:
        return ""


def display_two_columns(report, extracted_data):
    # Convert the extracted_data to a formatted JSON string
    #json_str = json.dumps(extracted_data, indent=2, ensure_ascii=False)

    # Create HTML content with two columns
    html_content = f"""
    <div style="display: flex; width: 100%; flex-wrap: wrap;">
        <div style="flex: 1; padding: 10px; border-right: 2px solid #ccc; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
            <h3>Report:</h3>
            <pre style="white-space: pre-wrap; word-wrap: break-word;">{report}</pre>
        </div>
        <div style="flex: 1; padding: 10px; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
            <h3>Extracted Data:</h3>
            <pre style="white-space: pre-wrap; word-wrap: break-word;">{json_str}</pre>
        </div>
    </div>
    """
    display(HTML(html_content))

# Process reports and display in two columns
for index, row in df.iterrows():
    report = row['Report']
    json_str = process_report(report)

    if json_str:
        # Display the report and the extracted JSON data in two columns
        display_two_columns(report, json_str)
# Out:
#     <div style="display: flex; width: 100%; flex-wrap: wrap;">
#         <div style="flex: 1; padding: 10px; border-right: 2px solid #ccc; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Report:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">
# Intracranielle Thrombektomie (Perkutane arterielle Thrombektomie) vom 03.01.2018:
#
# Klinik, Fragestellung, Rechtfertigende Indikation: akuter Carotis-T-Verschluß nach Herzkatheter aufgefallen, genauer Symptombeginn unklar.
# Klinik, Fragestellung, Rechtfertigende Indikation:
# Hauptstammverschluss. Symptombeginn unklar. NIHSS ca. 18. Rekanalisation erbeten.
#
# Aufklärung und Einwilligung:
# Notfallindikation. Die Erhebung der Risikoanamnese sowie Aufklärung und Einwilligung d. Pat. waren infolge des klinischen Zustandes nicht möglich.
#
# Methodik und Befund:
# Untersuchung in Intubationsnarkose. Punktion der rechten A. femoralis communis. 8F-Schleuse, 8F-Führkatheter, 5F-Diagnostikkatheter. Platzierung des Führkatheters in die proximale A. carotis interna über den Diagnostikkatheter. Serienangiographie. Hier zeigt sich ein Verschluß der MCA unmittelbar am Abgang .Einbringen eines großlumigen Aspirationskatheters (6F-Sofia) in Teleskoptechnik (Rebar 18 Mikrokatheter; Traxcess Mikrodraht). Passage des Thrombus mit Mikrodraht und Mikrokatheter und Freisetzten eines preset pre 6-30 Stentretrievers. Retraktion des Retrievers unter kontinuierlicher Aspiration und Bergen eines mehrere Millimeter großen Thrombus. Die folgende Serienangiographie zeigt eine vollständige Rekanalisierung. In der Abschlußserie keine Gefäßocclusionen. Reaktionslose manuelle i.a. KM-Applikation. Biplanare Aufnahmetechnik, Flächendosisprodukt 7046 cGy x cm², Durchleuchtungszeit 9,1  Minuten. Verschluss mittels AngioSeal
#
# Ergebnis:
# Rekanalisation mittels Thrombusaspiration und Thrombektomie (TICI 3 ).
#
#
#
#
# Eintreffen Angiographie	13:15
# Punktionszeitpunkt	13:25
# Zeitpunkt 1. Serie Zielgefäß	13:36
# Zeitpunkt Hauptstammeröffnung	13:55
#
#
#
#
# </pre>
#         </div>
#         <div style="flex: 1; padding: 10px; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Extracted Data:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">{
#   "NIHSS_score": "18",
#   "symptom_onset": "unklar",
#   "occluded_vessel": "MCA",
#   "occlusion_side": "unklar",
#   "used materials": "8F-Schleuse, 8F-Führkatheter, 5F-Diagnostikkatheter, 6F-Sofia Aspirationskatheter, Rebar 18 Mikrokatheter, Traxcess Mikrodraht, preset pre 6-30 Stentretriever",
#   "medication": "keine Angabe",
#   "complications": "keine",
#   "outcome": "erfolgreich",
#   "TICI_score": "3",
#   "Area dose product": "7046 cGy x cm²",
#   "Fluoroscopy time": "9,1 Minuten",
#   "arrival_time": "13:15",
#   "puncture_time": "13:25",
#   "first_series_time": "13:36",
#   "artery_opening_time": "13:55"
# }</pre>
#         </div>
#     </div>
#     <div style="display: flex; width: 100%; flex-wrap: wrap;">
#         <div style="flex: 1; padding: 10px; border-right: 2px solid #ccc; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Report:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">
# Intracranielle Thrombektomie (Perkutane arterielle Thrombektomie) vom 03.01.2018:
#
# Klinik, Fragestellung, Rechtfertigende Indikation:
# M2-Verschluss rechts. Symptombeginn 14:30. NIHSS. Rekanalisation erbeten.
#
# Aufklärung und Einwilligung:
# Notfallindikation. Die Erhebung der Risikoanamnese sowie Aufklärung und Einwilligung d. Pat. waren infolge des klinischen Zustandes nicht möglich.
#
# Methodik und Befund:
# Untersuchung in Sedierung. Punktion der rechten A. femoralis communis. 8F-Schleuse, 8F-Führkatheter, 5F-Diagnostikkatheter. Platzierung des Führkatheters in die proximale rechte A. carotis interna über den Diagnostikkatheter. Serienangiographie. Hier zeigt sich die superiore M2-Division weiterhin verschlossen. Einbringen eines großlumigen Aspirationskatheters (6F-Sofia) in Teleskoptechnik (Headway 17 Mikrokatheter; Synchro Mikrodraht). Passage des Thrombus mit dem Mikrokatheter. Nachführen und Freisetzen eines Stent-Retrievers (pReset lite 4x20mm, LOT 314045). Unter kontinuierlicher Aspiration Retraktion des Stent-Retrievers und Bergen eines ca. 5mm langen Thrombus. Die folgende Serienangiographie zeigt eine vollständige Rekanalisierung. In der Abschlußserie keine Gefäßocclusionen. Reaktionslose manuelle i.a. KM-Applikation. Biplanare Aufnahmetechnik, Flächendosisprodukt 3141,8 cGy x cm², Durchleuchtungszeit 14:26  Minuten. Verschluss mittels AngioSeal.
#
# Ergebnis:
# Rekanalisation mittels Thrombusaspiration und Thrombektomie (TICI 3).
#
#
#
#
# Eintreffen Angiographie	22:16
# Punktionszeitpunkt	22:30
# Zeitpunkt 1. Serie Zielgefäß	22:44
# Zeitpunkt Hauptstammeröffnung	23:04
#
#
#
#
# </pre>
#         </div>
#         <div style="flex: 1; padding: 10px; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Extracted Data:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">{
#   "NIHSS_score": "NIHSS 3",
#   "symptom_onset": "14:30",
#   "occluded_vessel": "M2 rechts",
#   "occlusion_side": "rechts",
#   "used materials": "8F-Schleuse, 8F-Führkatheter, 5F-Diagnostikkatheter, 6F-Sofia, Headway 17 Mikrokatheter, Synchro Mikrodraht, pReset lite 4x20mm",
#   "medication": "keine Angabe",
#   "complications": "keine",
#   "outcome": "erfolgreich",
#   "TICI_score": "TICI 3",
#   "Area dose product": "3141,8 cGy x cm²",
#   "Fluoroscopy time": "14:26",
#   "arrival_time": "22:16",
#   "puncture_time": "22:30",
#   "first_series_time": "22:44",
#   "artery_opening_time": "23:04"
# }</pre>
#         </div>
#     </div>
#     <div style="display: flex; width: 100%; flex-wrap: wrap;">
#         <div style="flex: 1; padding: 10px; border-right: 2px solid #ccc; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Report:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">
# Intracranielle Thrombektomie (Perkutane arterielle Thrombektomie) vom 04.01.2018:
#
# Klinik, Fragestellung, Rechtfertigende Indikation:
# ACI/ Carotid-I Verschluss rechts. LWS am Vortag. Plegie links. Rekanalisation erbeten.
#
# Aufklärung und Einwilligung:
# Notfallindikation. Die Erhebung der Risikoanamnese sowie Aufklärung und Einwilligung d. Pat. waren infolge des klinischen Zustandes nicht möglich.
#
# Methodik und Befund:
# Untersuchung in Intubationsnarkose. Punktion der rechten A. femoralis communis. 8F-Schleuse, 8F-Führkatheter, 5F-Diagnostikkatheter. Platzierung des Führkatheters in die subbasale rechte A. carotis interna über den Diagnostikkatheter. Serienangiographie. Hier zeigt sich ein supraophthalmischer ACI-Verschluss. Einbringen eines großlumigen Aspirationskatheters (6F-Sofia) in Teleskoptechnik ( Mikrokatheter XT27; Synchro Mikrodraht). Passage der Okklusion mittels Mikroakatheter und -draht un Freisetzen eines Solitaire 6x30 mm Stent-Retrievers. Retraktion desselben unter kontinuierlicher manueller Aspiration und Bergen zweier jeweils ca. 8 mm langer Thromben. Die folgende Serienangiographie zeigt eine vollständige Rekanalisierung. In der Abschlussserie keine Gefäßocclusionen. Reaktionslose manuelle i.a. KM-Applikation. Biplanare Aufnahmetechnik, Flächendosisprodukt 2033 cGy x cm², Durchleuchtungszeit  9:57 Minuten. Verschluss mittels AngioSeal
#
# Ergebnis:
# Technisch erfolgreiche und angiographisch komplikationslose mechanische Thrombektomie eines Carotid-I Verschlusses mittels Solumbratechnik  (TICI 3).
#
#
#
#
# Eintreffen Angiographie	12:20
# Punktionszeitpunkt	12:38
# Zeitpunkt 1. Serie Zielgefäß	12:55
# Zeitpunkt Hauptstammeröffnung	13:05
#
#
#
# </pre>
#         </div>
#         <div style="flex: 1; padding: 10px; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Extracted Data:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">{
#   "NIHSS_score": "",
#   "symptom_onset": "",
#   "occluded_vessel": "ACI/ Carotid-I Verschluss rechts",
#   "occlusion_side": "rechts",
#   "used materials": "8F-Schleuse, 8F-Führkatheter, 5F-Diagnostikkatheter, großlumiger Aspirationskatheter (6F-Sofia), Mikrokatheter XT27, Synchro Mikrodraht, Solitaire 6x30 mm Stent-Retrievers",
#   "medication": "",
#   "complications": "",
#   "outcome": "erfolgreich",
#   "TICI_score": "TICI 3",
#   "Area dose product": "2033 cGy x cm²",
#   "Fluoroscopy time": "9:57 Minuten",
#   "arrival_time": "12:20",
#   "puncture_time": "12:38",
#   "first_series_time": "12:55",
#   "artery_opening_time": "13:05"
# }</pre>
#         </div>
#     </div>
#     <div style="display: flex; width: 100%; flex-wrap: wrap;">
#         <div style="flex: 1; padding: 10px; border-right: 2px solid #ccc; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Report:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">
# Intracranielle Thrombektomie (Perkutane arterielle Thrombektomie) vom 05.01.2018:
#
# Klinik, Fragestellung, Rechtfertigende Indikation:
# Mediagabelverschluss rechts. Klinik 10-minütige TIA um 11:00. NIHSS aktuell 0. Interdisziplinäre Entscheidung zur Thrombektomie.
#
# Aufklärung und Einwilligung:
# Notfallindikation. Die Erhebung der Risikoanamnese sowie Aufklärung und Einwilligung d. Pat. Erfolgten durch mich. Der Patient wurde auf die fehlende Evidenz zu seiner Situation aufgeklärt ebenso wie über das Für und Wider eines Thrombektomieversuchs.
#
# Methodik und Befund:
# Untersuchung in Sedierung. Punktion der rechten A. femoralis communis. 8F-Schleuse, 8F-Führkatheter, 5F-Diagnostikkatheter. Platzierung des Führkatheters in die subbasale A. carotis interna über den Diagnostikkatheter. Serienangiographie. Hier zeigt sich ein persistierender Verschluss der Mediagabel mit ausgedehntem Perfusionsdefizit bei guten leptomeningealen Kollateralen. Einbringen eines großlumigen Aspirationskatheters (6F-Sofia) in Teleskoptechnik (Rebar 18 Mikrokatheter; Synchro Mikrodraht). Passage des Thrombus mit dem Mikrokatheter. Hierunter Vorbringen des Sofia an den Thrombus. Unter kontinuierlicher manueller Aspiration Retraktion des Sofia und Bergen zweier ca. je 6-8 mm langer Thrombusteile. Die folgende Serienangiographie zeigt eine vollständige Rekanalisierung. In der Abschlussserie keine Gefäßocclusionen. Reaktionslose manuelle i.a. KM-Applikation. Biplanare Aufnahmetechnik, Flächendosisprodukt 1552 cGy x cm², Durchleuchtungszeit 6:33  Minuten. Verschluss mittels AngioSeal.
#
# Ergebnis:
# Technisch erfolgreiche und angiographisch sowie klinisch komplikationslose endovaskuläre mechanische Thrombektomie eines rechtsseitigen Mediagabelverschlusses mittels primärer Thrombusaspiration (TICI 3) bei asymptomatischem Patienten.
#
#
#
#
# Eintreffen Angiographie	16:45
# Punktionszeitpunkt	17:15
# Zeitpunkt 1. Serie Zielgefäß	17:24
# Zeitpunkt Hauptstammeröffnung	17:34
#
#
#
#
# </pre>
#         </div>
#         <div style="flex: 1; padding: 10px; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Extracted Data:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">{
#   "NIHSS_score": 0,
#   "symptom_onset": "11:00",
#   "occluded_vessel": "rechte A. carotis interna",
#   "occlusion_side": "rechts",
#   "used materials": "8F-Schleuse, 8F-Führkatheter, 5F-Diagnostikkatheter, 6F-Sofia",
#   "medication": "keine Angabe",
#   "complications": "keine",
#   "outcome": "erfolgreich",
#   "TICI_score": "TICI 3",
#   "Area dose product": "1552 cGy x cm²",
#   "Fluoroscopy time": "6:33 Minuten",
#   "arrival_time": "16:45",
#   "puncture_time": "17:15",
#   "first_series_time": "17:24",
#   "artery_opening_time": "17:34"
# }</pre>
#         </div>
#     </div>
#     <div style="display: flex; width: 100%; flex-wrap: wrap;">
#         <div style="flex: 1; padding: 10px; border-right: 2px solid #ccc; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Report:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">
# Intracranielle Thrombektomie (Perkutane arterielle Thrombektomie) vom 06.01.2018:
#
# Klinik, Fragestellung, Rechtfertigende Indikation:
# Hauptstammverschluss Media rechts. Symptombeginn 17:30. NIHSS 10. Rekanalisation erbeten.
#
# Aufklärung und Einwilligung:
# Notfallindikation. Die Erhebung der Risikoanamnese sowie Aufklärung und Einwilligung d. Pat. waren infolge des klinischen Zustandes nicht möglich.
#
# Methodik und Befund:
# Untersuchung in Sedierung. Punktion der rechten A. femoralis communis. 8F-Schleuse, 8F-Führkatheter, 5F-Diagnostikkatheter. Platzierung des Führkatheters in die distale A. carotis communis über den Diagnostikkatheter. Serienangiographie. Hier zeigt sich die rechte MCA unter i.v.-Lyse weiterhin partiell verschlossen. Einbringen eines großlumigen Aspirationskatheters (6F-Sofia) in Teleskoptechnik (Rebar 18 Mikrokatheter; Synchro Mikrodraht). Passage des Thrombus mit dem Mikrokatheter. Nachführen und Freisetzen eines Stent-Retrievers (Solitaire 2, 4x20mm). Unter kontinuierlicher Aspiration Retraktion des Stent-Retrievers. Die folgende Serienangiographie zeigt zwar eine Rekanalisierung des MCA-Hauptstammes, jedoch ist nun der parietale M2-Ast distal verschlossen. Dieser wird anschließend insgesamt zwei Mal mit dem Mikrokatheter sondiert, so dass ein Stent-Retriever (pResetLite 3x20) über dem Thrombus freigesetzt und retrahiert werden kann. Nach dem zweiten lokalen Thrombektomiemanöver komplette Rekanalisation auch des M2-Astes. In der Abschlußserie periphere (M4) Occlusion zweier parietaler Mediaäste. Reaktionslose manuelle i.a. KM-Applikation. Biplanare Aufnahmetechnik, Flächendosisprodukt 7924,9 cGy x cm², Durchleuchtungszeit 29:11  Minuten. Verschluss mittels AngioSeal
#
#
# Ergebnis:
# Rekanalisation der rechten MCA mittels Thrombusaspiration und Thrombektomie (TICI 2b).
#
#
#
#
# Eintreffen Angiographie	19:28
# Punktionszeitpunkt	19:50
# Zeitpunkt 1. Serie Zielgefäß	20:14
# Zeitpunkt Hauptstammeröffnung	20:25
#
#
#
#
# </pre>
#         </div>
#         <div style="flex: 1; padding: 10px; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Extracted Data:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">{
#   "NIHSS_score": "10",
#   "symptom_onset": "17:30",
#   "occluded_vessel": "MCA",
#   "occlusion_side": "rechts",
#   "used materials": "8F-Schleuse, 8F-Führkatheter, 5F-Diagnostikkatheter, 6F-Sofia, Rebar 18 Mikrokatheter, Synchro Mikrodraht, Solitaire 2, 4x20mm, pResetLite 3x20",
#   "medication": "i.v.-Lyse",
#   "complications": "periphere (M4) Occlusion zweier parietaler Mediaäste",
#   "outcome": "Rekanalisation (TICI 2b)",
#   "TICI_score": "2b",
#   "Area dose product": "7924,9 cGy x cm²",
#   "Fluoroscopy time": "29:11 Minuten",
#   "arrival_time": "19:28",
#   "puncture_time": "19:50",
#   "first_series_time": "20:14",
#   "artery_opening_time": "20:25"
# }</pre>
#         </div>
#     </div>
#     <div style="display: flex; width: 100%; flex-wrap: wrap;">
#         <div style="flex: 1; padding: 10px; border-right: 2px solid #ccc; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Report:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">
# Intracranielle Thrombektomie (Perkutane arterielle Thrombektomie) vom 08.01.2018:
#
# Klinik, Fragestellung, Rechtfertigende Indikation: M1-Verschluß links. Lyse nicht möglich. Akute Klinik.
#
# Befund/Beurteilung
# "	Leistenpunktion 22.57 Uhr (Freigabe Anästhesie 22:53 Uhr). Ende der Intervention: 0:45 Uhr.
# "	Vorbekannte Dissektion der ACI links , Sondierung erschwert, doch letztlich auch mit dem Intermediärkatheter möglich.
# "	Letztlich leider frustraner Rekanalisationsversuch (Aspiration und Thrombektomie mit insgesamt 6 Manövern) ohne Eröffnung des Gefäßsegments.
# "	Material: Es wurden zwei Intermediärkatheter verwendet da sich der Sofia-5F als zu kurz erwiesen Danach Wechsel auf einen Sofia-6F Plus. Zudem wurde ein Trevo- und Phenox Stentretriever verwendet. Verschluß mit Angio-Seal.
#
#
# </pre>
#         </div>
#         <div style="flex: 1; padding: 10px; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Extracted Data:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">{
#   "NIHSS_score": "",
#   "symptom_onset": "",
#   "occluded_vessel": "M1",
#   "occlusion_side": "links",
#   "used materials": "Intermediärkatheter, Sofia-5F, Sofia-6F Plus, Trevo- und Phenox Stentretriever, Angio-Seal",
#   "medication": "",
#   "complications": "frustraner Rekanalisationsversuch",
#   "outcome": "erfolglos",
#   "TICI_score": "",
#   "Area dose product": "",
#   "Fluoroscopy time": "45 Minuten",
#   "arrival_time": "22:57",
#   "puncture_time": "22:57",
#   "first_series_time": "23:42",
#   "artery_opening_time": ""
# }</pre>
#         </div>
#     </div>
#     <div style="display: flex; width: 100%; flex-wrap: wrap;">
#         <div style="flex: 1; padding: 10px; border-right: 2px solid #ccc; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Report:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">
# Intracranielle Thrombektomie vom 09.01.2018:
#
# Klinik, Fragestellung, Rechtfertigende Indikation:
# Hauptstammverschluss. Symptombeginn 10:00. NIHSS 21. Rekanalisation erbeten.
#
# Aufklärung und Einwilligung:
# Notfallindikation. Die Erhebung der Risikoanamnese sowie Aufklärung und Einwilligung d. Pat. waren infolge des klinischen Zustandes nicht möglich.
#
# Methodik und Befund:
# Untersuchung in Intubationsnarkose. Punktion der rechten A. femoralis communis. 8F-Schleuse, 8F-Führkatheter, 5F-Diagnostikkatheter. Platzierung des Führkatheters in die proximale rechte A. carotis interna über den Diagnostikkatheter. Serienangiographie. Hier zeigt sich ein persistierender distaler Verschluss der ACI. Einbringen eines großlumigen Aspirationskatheters (6F-Sofia) in Teleskoptechnik ( Mikrokatheter X-celsior; Synchro Mikrodraht) bis an den Thrombus. Kontinuierliche Aspiration und Bergen eines insgesamt ca. 18 mm langen Thrombus in drei Durchgängen. Die folgende Serienangiographie zeigt eine vollständige Rekanalisierung des Mediastromgebietes bei persistierendem Verschluss des A1-Segmentes und einem umspülten Thrombus in der PcomA. In der Abschlußserie keine Gefäßocclusionen. Reaktionslose manuelle i.a. KM-Applikation. Biplanare Aufnahmetechnik, Flächendosisprodukt 6298 cGy x cm², Durchleuchtungszeit 18.4  Minuten. Verschluss mittels AngioSeal.
#
# Bei legen der Schleuse kommt es zu einer Dissektion in der rechten Beckenachse. Diese zeigt am Ende der Intervention keine hämodynamische Relevanz.
#
# Ergebnis:
# "	Rekanalisation mittels Thrombusaspiration des linken Mediastromgebietes (TICI 3) Persistierender Verschluss des linken A1-Segmentes und umspülter Thrombus in der PcomA.
# "	Kontrolle der Fußpulse rechts nach Dissektion der Iliacalgefäße.
#
#
#
#
#
# </pre>
#         </div>
#         <div style="flex: 1; padding: 10px; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Extracted Data:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">{
#   "NIHSS_score": "21",
#   "symptom_onset": "10:00",
#   "occluded_vessel": "ACI",
#   "occlusion_side": "nicht zutreffend",
#   "used materials": "8F-Schleuse, 8F-Führkatheter, 5F-Diagnostikkatheter, großlumiger Aspirationskatheter (6F-Sofia), Mikrokatheter X-celsior, Synchro Mikrodraht",
#   "medication": "reaktionslose manuelle i.a. KM-Applikation",
#   "complications": "Dissektion in der rechten Beckenachse",
#   "outcome": "Rekanalisation (TICI 3)",
#   "TICI_score": "3",
#   "Area dose product": "6298 cGy x cm²",
#   "Fluoroscopy time": "18.4 Minuten",
#   "arrival_time": "",
#   "puncture_time": "",
#   "first_series_time": "",
#   "artery_opening_time": ""
# }</pre>
#         </div>
#     </div>
#     <div style="display: flex; width: 100%; flex-wrap: wrap;">
#         <div style="flex: 1; padding: 10px; border-right: 2px solid #ccc; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Report:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">
# Intracranielle Thrombektomie (Perkutane arterielle Thrombektomie) vom 09.01.2018:
#
# Klinik, Fragestellung, Rechtfertigende Indikation: CTA Basilaristhrombose, akute Klinik, Lyse erfolgt. Symptombeginn seit 16:00 Uhr.
#
# Klinik, Fragestellung, Rechtfertigende Indikation:
# Hauptstammverschluss. Symptombeginn . NIHSS . Rekanalisation erbeten.
#
# Aufklärung und Einwilligung:
# Notfallindikation. Die Erhebung der Risikoanamnese sowie Aufklärung und Einwilligung d. Pat. waren infolge des klinischen Zustandes nicht möglich.
#
# Methodik und Befund:
# Untersuchung in Intubationsnarkose. Punktion der rechten A. femoralis communis. 6F-Führschleuse, 5F-Diagnostikkatheter. Platzierung des Führkatheters in der proximalen linken A. vertebralis. Serienangiographie. Hier zeigt sich ein Verschluß der linken PCA, die BA wieder offen.
# Einbringen eines großlumigen Aspirationskatheters (5F-Sofia) in Teleskoptechnik (Mikrokatheter; Synchro Mikrodraht) bis in die BA. Anschließend Passage des Thrombus in der linken PCA mit einem Stentretriever (Trevo 3x20)  unter kontinuierliche Aspiration. Es konnte etwas Thrombusmaterial geborgen werden.
# Die folgende Serienangiographie zeigt eine Rekanalisierung der PCA, im distalen Abschnitt eine Astes der linken PCA noch etwas Restthrombusmaterial.
# Reaktionslose manuelle i.a. KM-Applikation. Biplanare Aufnahmetechnik. Verschluss mittels AngioSeal
#
# Ergebnis:
# Rekanalisation mittels Thrombusaspiration und Thrombektomie von thrombotischen Material in der linken PCA bei Z.n. Basilaristhrombose und Lyse. Gefäße wieder perfundiert. Noch etwas thrombotisches Material in einem Ast der linken PCA.
#
#
#
#
# Eintreffen Angiographie	20:25 Uhr
# Punktionszeitpunkt	21:05 Uhr
# Zeitpunkt 1. Serie Zielgefäß	21:13 Uhr
# Zeitpunkt Hauptstammeröffnung	21:30 Uhr
#
#
#
#
# </pre>
#         </div>
#         <div style="flex: 1; padding: 10px; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Extracted Data:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">{
#   "NIHSS_score": "nicht angegeben",
#   "symptom_onset": "16:00",
#   "occluded_vessel": "Basillaris",
#   "occlusion_side": "nicht zutreffend",
#   "used materials": "6F-Führschleuse, 5F-Diagnostikkatheter, großlumiger Aspirationskatheter (5F-Sofia), Mikrokatheter, Synchro Mikrodraht, Stentretriever (Trevo 3x20)",
#   "medication": "Lyse erfolgt, reaktionslose manuelle i.a. KM-Applikation",
#   "complications": "keine",
#   "outcome": "erfolgreich",
#   "TICI_score": "2b",
#   "Area dose product": "nicht angegeben",
#   "Fluoroscopy time": "nicht angegeben",
#   "arrival_time": "20:25",
#   "puncture_time": "21:05",
#   "first_series_time": "21:13",
#   "artery_opening_time": "21:30"
# }</pre>
#         </div>
#     </div>
#     <div style="display: flex; width: 100%; flex-wrap: wrap;">
#         <div style="flex: 1; padding: 10px; border-right: 2px solid #ccc; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Report:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">
# Intracranielle Thrombektomie (Perkutane arterielle Thrombektomie) vom 10.01.2018:
#
# Klinik, Fragestellung, Rechtfertigende Indikation:
# Akute vertebrobasiläre Ischämie seit 8:30 bei ausgeprägter Makroangiopathie und Multiinfarktsyndrom. Initialer NIHSS 4, später zunehmend. Mechanische Rekanalisation unter i.v.-Lyse erbeten.
#
# Aufklärung und Einwilligung:
# Notfallindikation. Die Erhebung der Risikoanamnese sowie Aufklärung und Einwilligung d. Pat. waren infolge des klinischen Zustandes nicht möglich.
#
# Methodik und Befund:
# Untersuchung in Intubationsnarkose. Punktion der rechten A. femoralis communis. 6F-Schleuse, 6F-Führkatehter. Platzierung des Führkatheters in das V2-Segment der rechten A. vertebralis über einen großlumigen Aspirationskatheters (5F-Sofia). Serienangiographie. Hier zeigt sich das V4-Segment weiterhin verschlossen. Platzierung des Aspirationskatheters im V3-Segment. Problemlose Passage der Occlusion mit dem Mikrokatheter (Rebar-18 Mikrokatheter; Synchro Mikrodraht). Nachführen und Freisetzen eines Stent-Retrievers (pReset 4x20mm). Unter kontinuierlicher Aspiration Retraktion des Stent-Retrievers und Bergen eines ca. 5mm langen Thrombus. Die folgende Serienangiographie zeigt das V4-Segment wieder rekanalisiert. Eine verbleibende Stenose wird anschließend mit einem 2,5mm-PTA-Ballon dillatiert. Weiterhin Verschluss der A. basilaris kurz vor dem Abgang der AICA - dieser lässt sich mit dem Mikrodraht nicht passieren. Zur Darstellung der Kollateraliversorgung wird sodann die linke A. femoralis communis punktiert und über eine 5F-Schleuse ein 5F-Vertebraliskatehter in die linke A. carotis interna geführt. Hier zeigt sich eine retrograde Perfusion der distalen A. basialris über die linke Pcom bis in das noch antegrad perfundierte Segment. Beendigung der Intervention. Reaktionslose manuelle i.a. KM-Applikation. Biplanare Aufnahmetechnik, Flächendosisprodukt 13007,2 cGy x cm², Durchleuchtungszeit 47:07  Minuten. Verschluss rechts mittels AngioSeal, links mittels Exoseal.
#
# Ergebnis:
# Rekanalisation und Ballon-PTA der rechten A. vertebralis im V4-Segment mittels Thrombusaspiration und Thrombektomie. Es verbleibt eine höchstgradige mehrsegegmentale Stenose der sowohl ante- als auch retrograd perfundierten A. basilaris.
#
#
#
#
# Eintreffen Angiographie	13:30
# Punktionszeitpunkt	14:00
# Zeitpunkt 1. Serie Zielgefäß	14:12
# Zeitpunkt Hauptstammeröffnung	14:58
#
#
#
#
#
# </pre>
#         </div>
#         <div style="flex: 1; padding: 10px; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Extracted Data:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">{
#   "NIHSS_score": 4,
#   "symptom_onset": "08:30",
#   "occluded_vessel": "A. vertebralis",
#   "occlusion_side": "nicht zutreffend",
#   "used materials": "6F-Schleuse, 6F-Führkatheter, 5F-Sofia, Rebar-18 Mikrokatheter, Synchro Mikrodraht, pReset 4x20mm Stent-Retrievers, 2,5mm-PTA-Ballon",
#   "medication": "i.v.-Lyse",
#   "complications": "keine",
#   "outcome": "erfolgreich",
#   "TICI_score": "3",
#   "Area dose product": "13007,2 cGy x cm²",
#   "Fluoroscopy time": "47:07 Minuten",
#   "arrival_time": "13:30",
#   "puncture_time": "14:00",
#   "first_series_time": "14:12",
#   "artery_opening_time": "14:58"
# }</pre>
#         </div>
#     </div>
#     <div style="display: flex; width: 100%; flex-wrap: wrap;">
#         <div style="flex: 1; padding: 10px; border-right: 2px solid #ccc; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Report:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">
# Intracranielle Thrombektomie (Perkutane arterielle Thrombektomie) vom 10.01.2018:
#
# Klinik, Fragestellung, Rechtfertigende Indikation:
# Basilarisverschluß. Klinik, Fragestellung, Rechtfertigende Indikation:
# Hauptstammverschluss. Symptombeginn . NIHSS . Rekanalisation erbeten.
#
# Aufklärung und Einwilligung:
# Notfallindikation. Die Erhebung der Risikoanamnese sowie Aufklärung und Einwilligung d. Pat. waren infolge des klinischen Zustandes nicht möglich.
#
# Methodik und Befund:
# Untersuchung in Intubationsnarkose. Punktion der rechten A. femoralis communis. 8F-Schleuse, 8F-Führkatheter, 5F-Diagnostikkatheter. Platzierung des Führkatheters in die proximale A. carotis interna über den Diagnostikkatheter. Serienangiographie. Hier zeigt sich ein Abbruch der A. basilaris proximal. Einbringen eines großlumigen Aspirationskatheters (6F-Sofia) in Teleskoptechnik (Rebar 18 Mikrokatheter; Traxcess Mikrodraht) bis an den Thrombus. Kontinuierliche Aspiration und Bergen eines ca. 4 mm langen Thrombus. Die folgende Serienangiographie zeigt zunächst eine vollständige Rekanalisierung. Zudem erkennt man eine mäßig- bis höhergradige kurzstreckige Stenosierung, die offenbar die Grundlage des Verschlusses darstellt. Zunächst bei gutem Ergebnis Rückzug. Bei Kontrolldarstellung der A. vertebralios proximal z.A. einer Dissektion bei initial etwas schwieriger Passage eines abgangsnahen Elongation fällt ein deutlich verlangsamter Fluß auf. Die intrakranielle Kontrolle zeigt dann einen frühen Reverschluß, der sich durch erneute Thrombektomie wiederum vollständig beseitigen läßt. Eine Kontrolldarstellung wenige Minuten später zeigt erneute Thrombusbildung im Bereich der Stenose, so daß eine erneute Thrombektomie durchgeführt wird und anschließend eine Thrombozytenhemmung mit Aggrastat / Tirofiban in halber gewichtsadaptierter Dosis nach dem sog. Bolusregime begonnen wird. Hierunter bleibt das Gefäß während einer ca. 20-minütigen Beobachtungszeit mit Kontrolldarstellungen offen. Beenden der Intervention.   In der Abschlußserie keine thrombembolischen Komplikationen. Reaktionslose manuelle i.a. KM-Applikation. Biplanare Aufnahmetechnik, Flächendosisprodukt 16310 cGy x cm², Durchleuchtungszeit 15,9  Minuten. Verschluss mittels AngioSeal
#
# Ergebnis:
# Rekanalisation mittels Thrombusaspiration und Thrombektomie bei Basilarisverschluß auf Basis einer proximalen Stenose. Zweimalig rascher Reverschluß und erneute, erfolgreiche Aspirationsthrombektomie (TICI 3 ). Nach Aufnahme einer Aggrastattherapie in halber gewichtsadpatierter Dosis nach sog. Bolusregime bleibt das Gefäß während einer ca. 20-minütigen Beobachtungszeit mit mehreren Kontrollserien stabil offen.
#
# Prozedere: Fortführen der Aggrastattherapie in unveränderter Dosis bis auf weiteres. Aufwachversuch. Falls Patient in relativ gutem Zustand, Umstellen auf orale doppelte TAH. Andernfalls bildgebende Kontrolle und entscheidung über weiteres Vorgehen in Abhängigkeit vom Befund.
#
#
# Door to groin: 01:08 h
# Groin to reperfusion (first). 00:09 h
#
# Eintreffen Angiographie	17:35
# Punktionszeitpunkt	17:52
# Zeitpunkt 1. Serie Zielgefäß	17:57
# Zeitpunkt Hauptstammeröffnung	18:01
#
#
#
# </pre>
#         </div>
#         <div style="flex: 1; padding: 10px; max-width: 50%; word-wrap: break-word; white-space: pre-wrap;">
#             <h3>Extracted Data:</h3>
#             <pre style="white-space: pre-wrap; word-wrap: break-word;">{
#   "NIHSS_score": "",
#   "symptom_onset": "17:35",
#   "occluded_vessel": "Basillaris",
#   "occlusion_side": "nicht zutreffend",
#   "used materials": "8F-Schleuse, 8F-Führkatheter, 5F-Diagnostikkatheter, 6F-Sofia, Rebar 18 Mikrokatheter, Traxcess Mikrodraht",
#   "medication": "Aggrastat / Tirofiban",
#   "complications": "Dissektion",
#   "outcome": "teilweise erfolgreich",
#   "TICI_score": "3",
#   "Area dose product": "16310 cGy x cm²",
#   "Fluoroscopy time": "15,9 Minuten",
#   "arrival_time": "17:35",
#   "puncture_time": "17:52",
#   "first_series_time": "17:57",
#   "artery_opening_time": "18:01"
# }</pre>
#         </div>
#     </div>
